# %%
import pandas as pd

# %%
data = pd.read_csv("country_level_data.csv")

# %%
codebook = pd.read_csv("country_level_codebook.csv")

# %%
codebook.head()
# Out:
#   regionID iso3c    country_name incomeID  \
# 0      EAS   ASM  American Samoa      UMC
# 1      EAS   ASM  American Samoa      UMC
# 2      EAS   ASM  American Samoa      UMC
# 3      EAS   ASM  American Samoa      UMC
# 4      EAS   ASM  American Samoa      UMC
#
#                               measurement units    year  \
# 0  composition_food_organic_waste_percent     %  2011.0
# 1               composition_glass_percent     %  2011.0
# 2               composition_metal_percent     %  2011.0
# 3               composition_other_percent     %  2011.0
# 4     composition_paper_cardboard_percent     %  2011.0
#
#                                               source  \
# 0  SPREP (Secretariat of the Pacific Regional Env...
# 1  SPREP (Secretariat of the Pacific Regional Env...
# 2  SPREP (Secretariat of the Pacific Regional Env...
# 3  SPREP (Secretariat of the Pacific Regional Env...
# 4  SPREP (Secretariat of the Pacific Regional Env...
#
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   iso3c region_id country_name income_id           gdp  \
# 0   ABW       LCN        Aruba       HIC  35563.312500
# 1   AFG       SAS  Afghanistan       LIC   2057.062256
# 2   AGO       SSF       Angola       LMC   8036.690430
# 3   ALB       ECS      Albania       UMC  13724.058594
# 4   AND       ECS      Andorra       HIC  43711.800781
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
# 1                                     NaN                        NaN
# 2                                    51.8                        6.7
# 3                                    51.4                        4.5
# 4                                    31.2                        8.2
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# ...

# %%
words_to_remove = ['treatment', 'collection']
filtered_columns = df.filter(regex=f'.*{words_to_remove}.*', axis=1)
df_filtered = df.drop(columns=filtered_columns.columns)

# %%
df_filtered.head()
# Out:
#   iso3c region_id country_name income_id           gdp  \
# 0   ABW       LCN        Aruba       HIC  35563.312500
# 1   AFG       SAS  Afghanistan       LIC   2057.062256
# 2   AGO       SSF       Angola       LMC   8036.690430
# 3   ALB       ECS      Albania       UMC  13724.058594
# 4   AND       ECS      Andorra       HIC  43711.800781
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
# 1                                     NaN                        NaN
# 2                                    51.8                        6.7
# 3                                    51.4                        4.5
# 4                                    31.2                        8.2
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# ...

# %%
selected_columns_df = df_filtered[['iso3c', 'region_id', 'country_name', 'income_id', 'gdp', 'population_population_number_of_people', 'total_msw_total_msw_generated_tons_year']]
